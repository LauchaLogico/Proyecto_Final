# %%
import pandas as pd
import datetime
import matplotlib.pyplot as plt

# %%
df = pd.read_json(r'C:\Users\anavi\OneDrive\Escritorio\Grupal_Henry\bases_desc\Google Maps\Google Maps-20250205T161910Z-001\Google Maps\reviews-estados\review-Massachusetts\16.json', lines=True)

# %%
df.head()
# Out:
#         user_id             name           time  rating  \
# 0  1.118831e+20  Carmen De Jesus  1532303239396       5
# 1  1.033492e+20  kathie Chartier  1534592447635       5
# 2  1.093899e+20    Francis Smith  1575371884502       5
# 3  1.076305e+20      Kerrie Topi  1526776318490       4
# 4  1.025482e+20    Jason Schmidt  1581980567039       5
#
#                                   text  pics  resp  \
# 0                            Good wine  None  None
# 1                    Awesome selection  None  None
# 2  Liquor selection beyond expectation  None  None
# 3                 Great wine selection  None  None
# 4                              Not bad  None  None
#
#                                  gmap_id
# 0  0x89e40887d6d58239:0xa7c8ea10076dba64
# 1  0x89e40887d6d58239:0xa7c8ea10076dba64
# 2  0x89e40887d6d58239:0xa7c8ea10076dba64
# 3  0x89e40887d6d58239:0xa7c8ea10076dba64
# 4  0x89e40887d6d58239:0xa7c8ea10076dba64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 8 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   user_id  150000 non-null  float64
#  1   name     150000 non-null  object
#  2   time     150000 non-null  int64
#  3   rating   150000 non-null  int64
#  4   text     77803 non-null   object
#  5   pics     3856 non-null    object
#  6   resp     11060 non-null   object
#  7   gmap_id  150000 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 9.2+ MB

# %%
df.describe()
# Out:
#             user_id          time         rating
# count  1.500000e+05  1.500000e+05  150000.000000
# mean   1.091871e+20  1.547510e+12       4.285113
# std    5.350542e+18  4.064311e+10       1.032120
# min    1.000002e+20  1.032480e+12       1.000000
# 25%    1.045289e+20  1.521799e+12       4.000000
# 50%    1.091699e+20  1.550282e+12       5.000000
# 75%    1.138538e+20  1.574462e+12       5.000000
# max    1.184466e+20  1.621000e+12       5.000000

# %%
df.isnull().sum()
# Out:
# user_id         0
# name            0
# time            0
# rating          0
# text        72197
# pics       146144
# resp       138940
# gmap_id         0
# dtype: int64

# %%
df[df['text'].isna()].head()
# Out:
#           user_id              name           time  rating  text  pics  resp  \
# 115  1.098193e+20    David Figueroa  1551963769459       5  None  None  None
# 116  1.041769e+20      pat jennings  1559426798357       2  None  None  None
# 117  1.102561e+20  Steven Auerswald  1526645860027       5  None  None  None
# 118  1.007425e+20      Sarah Wilson  1576562530090       5  None  None  None
# 119  1.113382e+20        Mark Ellis  1593977831061       5  None  None  None
#
#                                    gmap_id
# 115  0x89e40887d6d58239:0xa7c8ea10076dba64
# 116  0x89e40887d6d58239:0xa7c8ea10076dba64
# 117  0x89e40887d6d58239:0xa7c8ea10076dba64
# 118  0x89e40887d6d58239:0xa7c8ea10076dba64
# 119  0x89e40887d6d58239:0xa7c8ea10076dba64

# %%
df_t = df.copy()

# %%
df_t['date'] = df_t['time'].apply(lambda x: datetime.datetime.utcfromtimestamp(x / 1000).strftime('%Y-%m-%d %H:%M:%S'))

# %%
df_t.head()
# Out:
#         user_id             name           time  rating  \
# 0  1.118831e+20  Carmen De Jesus  1532303239396       5
# 1  1.033492e+20  kathie Chartier  1534592447635       5
# 2  1.093899e+20    Francis Smith  1575371884502       5
# 3  1.076305e+20      Kerrie Topi  1526776318490       4
# 4  1.025482e+20    Jason Schmidt  1581980567039       5
#
#                                   text  pics  resp  \
# 0                            Good wine  None  None
# 1                    Awesome selection  None  None
# 2  Liquor selection beyond expectation  None  None
# 3                 Great wine selection  None  None
# 4                              Not bad  None  None
#
#                                  gmap_id                 date
# 0  0x89e40887d6d58239:0xa7c8ea10076dba64  2018-07-22 23:47:19
# 1  0x89e40887d6d58239:0xa7c8ea10076dba64  2018-08-18 11:40:47
# 2  0x89e40887d6d58239:0xa7c8ea10076dba64  2019-12-03 11:18:04
# 3  0x89e40887d6d58239:0xa7c8ea10076dba64  2018-05-20 00:31:58
# 4  0x89e40887d6d58239:0xa7c8ea10076dba64  2020-02-17 23:02:47

# %%
df_t.shape
# Out:
# (150000, 9)

# %%
df_t['date'] = pd.to_datetime(df_t['date'], errors='coerce')
df_t['year'] = df_t['date'].dt.year

# %%
df_t.head()
# Out:
#         user_id             name           time  rating  \
# 0  1.118831e+20  Carmen De Jesus  1532303239396       5
# 1  1.033492e+20  kathie Chartier  1534592447635       5
# 2  1.093899e+20    Francis Smith  1575371884502       5
# 3  1.076305e+20      Kerrie Topi  1526776318490       4
# 4  1.025482e+20    Jason Schmidt  1581980567039       5
#
#                                   text  pics  resp  \
# 0                            Good wine  None  None
# 1                    Awesome selection  None  None
# 2  Liquor selection beyond expectation  None  None
# 3                 Great wine selection  None  None
# 4                              Not bad  None  None
#
#                                  gmap_id                date  year
# 0  0x89e40887d6d58239:0xa7c8ea10076dba64 2018-07-22 23:47:19  2018
# 1  0x89e40887d6d58239:0xa7c8ea10076dba64 2018-08-18 11:40:47  2018
# 2  0x89e40887d6d58239:0xa7c8ea10076dba64 2019-12-03 11:18:04  2019
# 3  0x89e40887d6d58239:0xa7c8ea10076dba64 2018-05-20 00:31:58  2018
# 4  0x89e40887d6d58239:0xa7c8ea10076dba64 2020-02-17 23:02:47  2020

# %%
df_filtrado = df_t[df_t['gmap_id'] == "0x89e40887d6d58239:0xa7c8ea10076dba64"]
dimensiones = df_filtrado.shape

# %%
df_filtrado
# Out:
#           user_id                  name           time  rating  \
# 0    1.118831e+20       Carmen De Jesus  1532303239396       5
# 1    1.033492e+20       kathie Chartier  1534592447635       5
# 2    1.093899e+20         Francis Smith  1575371884502       5
# 3    1.076305e+20           Kerrie Topi  1526776318490       4
# 4    1.025482e+20         Jason Schmidt  1581980567039       5
# ..            ...                   ...            ...     ...
# 616  1.073303e+20  Adrian Kerr-Delworth  1514474518626       5
# 617  1.109460e+20           Shweta Raut  1553867930786       5
# 618  1.080054e+20             Arunas Tr  1505526253548       5
# 619  1.119654e+20       Gregory Ansaldi  1524012711542       5
# 620  1.017860e+20   Harrison Czajkowski  1531084582352       5
#
#                                     text  pics  resp  \
# 0                              Good wine  None  None
# 1                      Awesome selection  None  None
# 2    Liquor selection beyond expectation  None  None
# 3                   Great wine selection  None  None
# 4                                Not bad  None  None
# ..                                   ...   ...   ...
# 616                                 None  None  None
# 617                                 None  None  None
# 618                                 None  None  None
# 619                                 None  None  None
# 620                                 None  None  None
#
#                                    gmap_id                date  year
# 0    0x89e40887d6d58239:0xa7c8ea10076dba64 2018-07-22 23:47:19  2018
# 1    0x89e40887d6d58239:0xa7c8ea10076dba64 2018-08-18 11:40:47  2018
# 2    0x89e40887d6d58239:0xa7c8ea10076dba64 2019-12-03 11:18:04  2019
# 3    0x89e40887d6d58239:0xa7c8ea10076dba64 2018-05-20 00:31:58  2018
# 4    0x89e40887d6d58239:0xa7c8ea10076dba64 2020-02-17 23:02:47  2020
# ..                                     ...                 ...   ...
# 616  0x89e40887d6d58239:0xa7c8ea10076dba64 2017-12-28 15:21:58  2017
# 617  0x89e40887d6d58239:0xa7c8ea10076dba64 2019-03-29 13:58:50  2019
# 618  0x89e40887d6d58239:0xa7c8ea10076dba64 2017-09-16 01:44:13  2017
# 619  0x89e40887d6d58239:0xa7c8ea10076dba64 2018-04-18 00:51:51  2018
# 620  0x89e40887d6d58239:0xa7c8ea10076dba64 2018-07-08 21:16:22  2018
#
# [621 rows x 10 columns]

# %%
dimensiones
# Out:
# (621, 10)

# %%
df_avg_rating = df_filtrado.groupby('year')['rating'].mean()

# Graficar
plt.figure(figsize=(10, 5))
plt.plot(df_avg_rating.index, df_avg_rating.values, marker='o', linestyle='-')
plt.xlabel('Year')
plt.ylabel('Average Rating')
plt.title('Average Rating per Year')
plt.grid(True)
plt.show()

# %%
resumen = df_filtrado.groupby('year').agg(
    avg_rating=('rating', 'mean'),   # Promedio de rating
    total_votes=('year', 'sum') # Total de votos
).reset_index()

# %%
resumen
# Out:
#    year  avg_rating  total_votes
# 0  2017    4.769841       254142
# 1  2018    4.680751       429834
# 2  2019    4.622517       304869
# 3  2020    4.682692       210080
# 4  2021    4.555556        54567
