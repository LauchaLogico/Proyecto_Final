# %%
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_user = pd.read_parquet(r'C:\Users\anavi\OneDrive - Universidad de La Salle\GitHub\Grupal_Henry\bases_desc\user-001.parquet')

# %%
df_user.head() # Para visualizar los datos que tenemos de la base de usuarios
# Out:
#                   user_id    name  review_count        yelping_since  useful  \
# 0  qVc8ODYU5SZjKXVBgXdI7w  Walker           585  2007-01-25 16:47:26    7217
# 1  j14WgRoU_-2ZE1aw1dXrJg  Daniel          4333  2009-01-25 04:35:42   43091
# 2  2WnXYQFK0hXEoTxPtV2zvg   Steph           665  2008-07-25 10:41:00    2086
# 3  SZDeASXq7o05mMNLshsdIA    Gwen           224  2005-11-29 04:38:33     512
# 4  hA5lMy-EnncsH4JoR-hFGQ   Karen            79  2007-01-05 19:40:59      29
#
#    funny   cool                                              elite  \
# 0   1259   5994                                               2007
# 1  13066  27281  2009,2010,2011,2012,2013,2014,2015,2016,2017,2...
# 2   1010   1003                           2009,2010,2011,2012,2013
# 3    330    299                                     2009,2010,2011
# 4     15      7
#
#                                              friends  fans  ...  \
# 0  NSCy54eWehBJyZdG2iE84w, pe42u7DcCH2QmI81NX-8qA...   267  ...
# ...

# %%
df_user.shape
# Out:
# (2105597, 22)

# %%
df_user.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2105597 entries, 0 to 2105596
# Data columns (total 22 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   user_id             object
#  1   name                object
#  2   review_count        int64
#  3   yelping_since       object
#  4   useful              int64
#  5   funny               int64
#  6   cool                int64
#  7   elite               object
#  8   friends             object
#  9   fans                int64
#  10  average_stars       float64
#  11  compliment_hot      int64
#  12  compliment_more     int64
#  13  compliment_profile  int64
#  14  compliment_cute     int64
#  15  compliment_list     int64
#  16  compliment_note     int64
#  17  compliment_plain    int64
#  18  compliment_cool     int64
#  19  compliment_funny    int64
#  20  compliment_writer   int64
#  21  compliment_photos   int64
# dtypes: float64(1), int64(16), object(5)
# memory usage: 353.4+ MB

# %%
df_user.describe()
# Out:
#        review_count        useful         funny          cool          fans  \
# count  2.105597e+06  2.105597e+06  2.105597e+06  2.105597e+06  2.105597e+06
# mean   2.846875e+01  5.516853e+01  2.267667e+01  3.143013e+01  1.913746e+00
# std    1.042146e+02  7.388068e+02  4.628811e+02  6.379274e+02  2.436510e+01
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    6.000000e+00  3.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 75%    1.900000e+01  1.500000e+01  3.000000e+00  4.000000e+00  0.000000e+00
# max    1.747300e+04  2.062960e+05  1.858230e+05  1.998780e+05  1.249700e+04
#
#        average_stars  compliment_hot  compliment_more  compliment_profile  \
# count   2.105597e+06    2.105597e+06     2.105597e+06        2.105597e+06
# mean    3.641863e+00    2.444596e+00     3.968618e-01        2.532631e-01
# ...

# %%
df_user.isnull().sum()
# Out:
# user_id               0
# name                  0
# review_count          0
# yelping_since         0
# useful                0
# funny                 0
# cool                  0
# elite                 0
# friends               0
# fans                  0
# average_stars         0
# compliment_hot        0
# compliment_more       0
# compliment_profile    0
# compliment_cute       0
# compliment_list       0
# compliment_note       0
# compliment_plain      0
# compliment_cool       0
# compliment_funny      0
# compliment_writer     0
# compliment_photos     0
# dtype: int64

# %%
df_user.nlargest(10, 'review_count')[['name', 'review_count']].plot(kind='bar', x='name', y='review_count')
# Out:
# <Axes: xlabel='name'>

# %%
# Relación entre fans y average_stars (Dispersión)
sns.scatterplot(data=df_user, x='fans', y='average_stars')
# Out:
# <Axes: xlabel='fans', ylabel='average_stars'>

# %%
# Se observa un outlier, quiero eliminarlo para visualizar mejor la dispersión
df_user_clean = df_user[df_user['fans'] <= 4500]

plt.figure(figsize=(8,6))
sns.scatterplot(data=df_user_clean, x='fans', y='average_stars')
plt.show()

# %%
#Correlación entre useful, funny, cool y compliment_* (Mapa de calor)
sns.heatmap(df_user[['useful', 'funny', 'cool', 'fans', 'compliment_hot', 'compliment_cool']].corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
df_user.columns
# Out:
# Index(['user_id', 'name', 'review_count', 'yelping_since', 'useful', 'funny',
#        'cool', 'elite', 'friends', 'fans', 'average_stars', 'compliment_hot',
#        'compliment_more', 'compliment_profile', 'compliment_cute',
#        'compliment_list', 'compliment_note', 'compliment_plain',
#        'compliment_cool', 'compliment_funny', 'compliment_writer',
#        'compliment_photos'],
#       dtype='object')

# %%
#df_user['yelping_since_year'].value_counts().sort_index().plot(kind='line')

# %%
df_business = pd.read_pickle(r'C:\Users\anavi\OneDrive - Universidad de La Salle\GitHub\Grupal_Henry\bases_desc\business.pkl')

# %%
df_business.head()
# Out:
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara   NaN       93101
# 1  87 Grasso Plaza Shopping Center         Affton   NaN       63123
# 2             5255 E Broadway Blvd         Tucson   NaN       85711
# 3                      935 Race St   Philadelphia    CA       19107
# 4                    101 Walnut St     Green Lane    MO       18054
#
#     latitude   longitude stars review_count  ... state postal_code latitude  \
# 0  34.426679 -119.711197   5.0            7  ...   NaN         NaN      NaN
# 1  38.551126  -90.335695   3.0           15  ...   NaN         NaN      NaN
# ...

# %%
df_business.shape
# Out:
# (150346, 28)

# %%
df_business.info
# Out:
# <bound method DataFrame.info of                    business_id                      name  \
# 0       Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1       mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2       tUFrWirKiKi_TAnsVWINQQ                    Target
# 3       MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4       mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# ...                        ...                       ...
# 150341  IUQopTMmYQG-qRtBk-8QnA              Binh's Nails
# 150342  c8GjPIOTGVmIemT7j5_SyQ      Wild Birds Unlimited
# 150343  _QAMST-NrQobXduilWEqSw         Claire's Boutique
# 150344  mtGm22y5c2UHNXDFAjaPNw  Cyclery & Fitness Center
# 150345  jV_XOycEzSlTx-65W906pg                   Sic Ink
#
#                                 address           city state postal_code  \
# 0                1616 Chapala St, Ste 2  Santa Barbara   NaN       93101
# 1       87 Grasso Plaza Shopping Center         Affton   NaN       63123
# ...

# %%
#df_business.describe()  #No se puede correr este comando hasta no se conviertan a datos las variables numericas que deberias ser categoricas

# %%
df_business.head(1)
# Out:
#               business_id                      name                 address  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ  1616 Chapala St, Ste 2
#
#             city state postal_code   latitude   longitude stars review_count  \
# 0  Santa Barbara   NaN       93101  34.426679 -119.711197   5.0            7
#
#    ... state postal_code latitude longitude stars review_count is_open  \
# 0  ...   NaN         NaN      NaN       NaN   NaN          NaN     NaN
#
#   attributes categories hours
# 0        NaN        NaN   NaN
#
# [1 rows x 28 columns]

# %%
df_business.columns
# Out:
# Index(['business_id', 'name', 'address', 'city', 'state', 'postal_code',
#        'latitude', 'longitude', 'stars', 'review_count', 'is_open',
#        'attributes', 'categories', 'hours', 'business_id', 'name', 'address',
#        'city', 'state', 'postal_code', 'latitude', 'longitude', 'stars',
#        'review_count', 'is_open', 'attributes', 'categories', 'hours'],
#       dtype='object')

# %%
df_business["address"].describe()
# Out:
#        address                address
# count   150346                      5
# unique  122844                      5
# top             8602 Hillsborough Ave
# freq      5127                      1

# %%
df_business["state"].describe()
# Out:
#          state state
# count   150343     5
# unique      27     5
# top         PA    LA
# freq     34039     1

# %%
df_business["state"].info
# Out:
# <bound method DataFrame.info of        state state
# 0        NaN   NaN
# 1        NaN   NaN
# 2        NaN   NaN
# 3         CA   NaN
# 4         MO   NaN
# ...      ...   ...
# 150341    IN   NaN
# 150342    DE   NaN
# 150343    AB   NaN
# 150344    AB   NaN
# 150345    TN   NaN
#
# [150346 rows x 2 columns]>

# %%
df_business["state"].head()
# Out:
#   state state
# 0   NaN   NaN
# 1   NaN   NaN
# 2   NaN   NaN
# 3    CA   NaN
# 4    MO   NaN

# %%
mitad = len(df_business.columns) // 2

df_business1 = df_business.iloc[:, :mitad]   # Primera mitad de columnas
df_business2 = df_business.iloc[:, mitad:]   # Segunda mitad de columnas

# %%
df_business1.head()
# Out:
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara   NaN       93101
# 1  87 Grasso Plaza Shopping Center         Affton   NaN       63123
# 2             5255 E Broadway Blvd         Tucson   NaN       85711
# 3                      935 Race St   Philadelphia    CA       19107
# 4                    101 Walnut St     Green Lane    MO       18054
#
#     latitude   longitude stars review_count is_open  \
# 0  34.426679 -119.711197   5.0            7       0
# 1  38.551126  -90.335695   3.0           15       1
# 2  32.223236 -110.880452   3.5           22       0
# ...

# %%
df_business1.shape
# Out:
# (150346, 14)

# %%
df_business1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 150346 entries, 0 to 150345
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   business_id   150346 non-null  object
#  1   name          150346 non-null  object
#  2   address       150346 non-null  object
#  3   city          150346 non-null  object
#  4   state         150343 non-null  object
#  5   postal_code   150346 non-null  object
#  6   latitude      150346 non-null  float64
#  7   longitude     150346 non-null  float64
#  8   stars         150346 non-null  object
#  9   review_count  150346 non-null  int32
#  10  is_open       150346 non-null  object
#  11  attributes    136602 non-null  object
#  12  categories    150346 non-null  object
#  13  hours         127123 non-null  object
# dtypes: float64(2), int32(1), object(11)
# memory usage: 20.7+ MB

# %%
valores_no_nulos = df_business2.stack()
valores_no_nulos.head()
# Out:
# 590  business_id    6_Zf2QsRHCH1RhbzA9inyw
#      name                        STarbucks
#      address         8602 Hillsborough Ave
#      city                            Tampa
#      state                              LA
# dtype: object

# %%
df_nonulos = df_business2.dropna()

# %%
df_nonulos
# Out:
#                  business_id       name                             address  \
# 590   6_Zf2QsRHCH1RhbzA9inyw  STarbucks               8602 Hillsborough Ave
# 613   Iipfa9Kaac9XH5Vo8GQwvg  STarbucks                     5956 153 Avenue
# 978   oY6osC4Ch3PvguA7D1hh_w  STarbucks                    1251 Route 130 S
# 1296  pxuMxh5oC7W-PDN9wwvozg  STarbucks                     219 N Center St
# 1543  lo2VbA7Lwzu3i23pQpmzlw  STarbucks  1125 S Black Horse Pike, Space 575
#
#                      city state postal_code   latitude   longitude stars  \
# 590                 Tampa    LA       33615   27.99637  -82.580954   3.0
# 613              Edmonton    PA     T5Y 2W1  53.616147 -113.432424   3.5
# 978           Cinnaminson    AZ       08077  40.000157  -74.987313   4.5
# 1296                 Reno    FL       89501  39.527772 -119.812518   3.0
# 1543  Gloucester Township    NJ       08012   39.78403   -75.05207   3.0
#
# ...

# %%
df_business1[df_business1["business_id"] == "6_Zf2QsRHCH1RhbzA9inyw"]
# Out:
#                 business_id       name                address   city state  \
# 590  6_Zf2QsRHCH1RhbzA9inyw  Starbucks  8602 Hillsborough Ave  Tampa    LA
#
#     postal_code  latitude  longitude stars review_count is_open  \
# 590       33615  27.99637 -82.580954   3.0           56       1
#
#                                             attributes          categories  \
# 590  {'BikeParking': 'True', 'BusinessAcceptsCredit...  Coffee & Tea, Food
#
#                                                  hours
# 590  {'Monday': '5:30-21:0', 'Tuesday': '5:30-21:0'...

# %%
df_business.iloc[613]
# Out:
# business_id                                Iipfa9Kaac9XH5Vo8GQwvg
# name                                                    Starbucks
# address                                           5956 153 Avenue
# city                                                     Edmonton
# state                                                          PA
# postal_code                                               T5Y 2W1
# latitude                                                53.616147
# longitude                                             -113.432424
# stars                                                         3.5
# review_count                                                   10
# is_open                                                         1
# attributes      {'BusinessParking': '{'garage': False, 'street...
# categories                                     Coffee & Tea, Food
# hours           {'Monday': '5:30-22:0', 'Tuesday': '5:30-22:0'...
# ...

# %% [markdown]
# Se encontró al hacer el EDA de la base de datos business que tenia todas las columnas duplicadas. Haciendo una limpieza, encontramos que al dividir el dataset en dos partes iguales (df_business1 y df_business2) pudimos identificar que solo 5 establecimientos (590, 613, 978, 1296 y 1543) del df_business2 tenian información, pero esta era la misma que habia en el dataset df_business1. Decidimos trabajar unicamente con df_business1.

# %%
#df_business1.describe()

# %%
df_business1['review_count'] = df_business1['review_count'].astype(int)
# Out:
# C:\Users\anavi\AppData\Local\Temp\ipykernel_33516\1792090798.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_business1['review_count'] = df_business1['review_count'].astype(int)

# %%
df_business1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 150346 entries, 0 to 150345
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   business_id   150346 non-null  object
#  1   name          150346 non-null  object
#  2   address       150346 non-null  object
#  3   city          150346 non-null  object
#  4   state         150343 non-null  object
#  5   postal_code   150346 non-null  object
#  6   latitude      150346 non-null  object
#  7   longitude     150346 non-null  object
#  8   stars         150346 non-null  object
#  9   review_count  150346 non-null  int32
#  10  is_open       150346 non-null  object
#  11  attributes    136602 non-null  object
#  12  categories    150243 non-null  object
#  13  hours         127123 non-null  object
# dtypes: int32(1), object(13)
# memory usage: 20.7+ MB

# %%
df_business1.describe()
# Out:
#         review_count
# count  150346.000000
# mean       44.866561
# std       121.120136
# min         5.000000
# 25%         8.000000
# 50%        15.000000
# 75%        37.000000
# max      7568.000000

# %%
df_bs100 = df_business1[df_business1["review_count"] >= 100]

# %%
# Convertir las columnas latitude y longitude a tipo float
df_business1['latitude'] = df_business1['latitude'].astype(float)
df_business1['longitude'] = df_business1['longitude'].astype(float)
# Out:
# C:\Users\anavi\AppData\Local\Temp\ipykernel_33516\1359055153.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_business1['latitude'] = df_business1['latitude'].astype(float)
# C:\Users\anavi\AppData\Local\Temp\ipykernel_33516\1359055153.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_business1['longitude'] = df_business1['longitude'].astype(float)

# %%
# Boxplot de la columna stars
plt.figure(figsize=(10, 6))
sns.boxplot(x=df_business1['stars'])
plt.title('Boxplot de Stars')
plt.xlabel('Stars')
plt.show()

# Diagrama de dispersión entre review_count y stars
plt.figure(figsize=(10, 6))
sns.scatterplot(x=df_business1['review_count'], y=df_business1['stars'])
plt.title('Diagrama de Dispersión entre Review Count y Stars')
plt.xlabel('Review Count')
plt.ylabel('Stars')
plt.show()

# %%
# Diagrama de dispersión entre review_count y stars
plt.figure(figsize=(10, 6))
sns.scatterplot(x=df_bs100['review_count'], y=df_bs100['stars'])
plt.title('Diagrama de Dispersión entre Review Count y Stars')
plt.xlabel('Review Count')
plt.ylabel('Stars')
plt.show()

# %%
df_bs100.head()
# Out:
#                business_id                     name             address  \
# 14  0bPLkL0QhhPO5kt1_EXmNQ     Zio's Italian Market       2575 E Bay Dr
# 15  MUTTqe8uqyMdBl186RmNeA                 Tuna Bar         205 Race St
# 19  ROeacJQwBeh05Rqg7F6TCg                      BAP       1224 South St
# 23  9OG5YkX1g2GReZM0AskizA  Romano's Macaroni Grill  5505 S Virginia St
# 27  tMkwHmWFUEXrC9ZduonpTg       The Green Pheasant       215 1st Ave S
#
#             city state postal_code   latitude   longitude stars  review_count  \
# 14         Largo    FL       33771  27.916116  -82.760461   4.5           100
# 15  Philadelphia    IN       19106  39.953949  -75.143226   4.0           245
# 19  Philadelphia    AZ       19147  39.943223  -75.162568   4.5           205
# 23          Reno    AB       89502  39.476117 -119.789339   2.5           339
# 27     Nashville    TN       37201  36.159886  -86.773197   4.0           161
#
# ...

# %%
df_bs100_4 = df_bs100[df_bs100["stars"] >= 5]

# %%
df_business1[df_business1["stars"] <= 3].shape
# Out:
# (49214, 14)

# %%
df_bs100_4.shape
# Out:
# (279, 14)

# %%
# Diagrama de dispersión entre review_count y stars
plt.figure(figsize=(10, 6))
sns.scatterplot(x=df_bs100_4['review_count'], y=df_bs100_4['stars'])
plt.title('Diagrama de Dispersión entre Review Count y Stars')
plt.xlabel('Review Count')
plt.ylabel('Stars')
plt.show()

# %%
df_bs100_4.shape
# Out:
# (12315, 14)

# %%
df_filtered = df_bs100_4[df_bs100_4['categories'] == 'Restaurants']
df_filtered
# Out:
# Empty DataFrame
# Columns: [business_id, name, address, city, state, postal_code, latitude, longitude, stars, review_count, is_open, attributes, categories, hours]
# Index: []

# %%
df_bs100_4.head(5)
# Out:
#                business_id                  name            address  \
# 14  0bPLkL0QhhPO5kt1_EXmNQ  Zio's Italian Market      2575 E Bay Dr
# 15  MUTTqe8uqyMdBl186RmNeA              Tuna Bar        205 Race St
# 19  ROeacJQwBeh05Rqg7F6TCg                   BAP      1224 South St
# 27  tMkwHmWFUEXrC9ZduonpTg    The Green Pheasant      215 1st Ave S
# 33  kV_Q1oqis8Qli8dUoGpTyQ         Ardmore Pizza  10 Rittenhouse Pl
#
#             city state postal_code   latitude  longitude stars  review_count  \
# 14         Largo    FL       33771  27.916116 -82.760461   4.5           100
# 15  Philadelphia    IN       19106  39.953949 -75.143226   4.0           245
# 19  Philadelphia    AZ       19147  39.943223 -75.162568   4.5           205
# 27     Nashville    TN       37201  36.159886 -86.773197   4.0           161
# 33       Ardmore    ID       19003  40.006707 -75.289671   3.5           109
#
#    is_open                                         attributes  \
# ...

# %%
#import pandas as pd

# Función para normalizar la columna "categories"
def normalize_entry(entry):
    if isinstance(entry, str):  
        categories = [cat.strip() for cat in entry.split(",")]  # Convertir a lista y eliminar espacios
        return pd.DataFrame({"category": categories})  # Crear DataFrame con una columna "category"
    else:
        return None  # Retorna None si el valor no es válido

expanded_dfs = []

# Iterar sobre las filas del DataFrame
for idx, row in df_bs100_4.iterrows():
    entry = row['categories']

    if pd.isna(entry) or entry == "":
        continue  # Saltar filas sin datos

    normalized_df = normalize_entry(entry)
    
    if normalized_df is not None and not normalized_df.empty:
        normalized_df['business_id'] = row['business_id']  # Mantener relación con el negocio
        expanded_dfs.append(normalized_df)

# Concatenar los DataFrames expandidos
df_categories = pd.concat(expanded_dfs, ignore_index=True) if expanded_dfs else pd.DataFrame()

# %%
df_categories
# Out:
#           category             business_id
# 0             Food  0bPLkL0QhhPO5kt1_EXmNQ
# 1            Delis  0bPLkL0QhhPO5kt1_EXmNQ
# 2          Italian  0bPLkL0QhhPO5kt1_EXmNQ
# 3         Bakeries  0bPLkL0QhhPO5kt1_EXmNQ
# 4      Restaurants  0bPLkL0QhhPO5kt1_EXmNQ
# ...            ...                     ...
# 66083         Bars  w_4xUt-1AyY2ZwKtnjW0Xg
# 66084   Gastropubs  w_4xUt-1AyY2ZwKtnjW0Xg
# 66085   Sandwiches  w_4xUt-1AyY2ZwKtnjW0Xg
# 66086    Nightlife  w_4xUt-1AyY2ZwKtnjW0Xg
# 66087  Restaurants  w_4xUt-1AyY2ZwKtnjW0Xg
#
# [66088 rows x 2 columns]

# %%
df_filtered = df_categories[df_categories["business_id"] == "0bPLkL0QhhPO5kt1_EXmNQ"]
df_filtered
# Out:
#       category             business_id
# 0         Food  0bPLkL0QhhPO5kt1_EXmNQ
# 1        Delis  0bPLkL0QhhPO5kt1_EXmNQ
# 2      Italian  0bPLkL0QhhPO5kt1_EXmNQ
# 3     Bakeries  0bPLkL0QhhPO5kt1_EXmNQ
# 4  Restaurants  0bPLkL0QhhPO5kt1_EXmNQ

# %%
category_counts = df_categories["category"].value_counts()# Contar cuántas veces aparece cada categoría y convertirlo en DataFrame
df_category_counts = df_categories["category"].value_counts().reset_index()
df_category_counts.columns = ["category", "count"]  # Renombrar columnas

# %%
df_category_counts.shape
# Out:
# (772, 2)

# %%
df_category_counts.head()
# Out:
#          category  count
# 0     Restaurants  10165
# 1            Food   3792
# 2       Nightlife   3354
# 3            Bars   3191
# 4  American (New)   2047

# %%
df_unique_categories = df_category_counts[df_category_counts["count"] == 1]

# %%
df_unique_categories.shape
# Out:
# (158, 2)

# %%
df_unique_categories.head()
# Out:
#              category  count
# 614            Clowns      1
# 615   Septic Services      1
# 616  Wildlife Control      1
# 617  Balloon Services      1
# 618   Gutter Services      1

# %%
df_categories
# Out:
#           category             business_id
# 0             Food  0bPLkL0QhhPO5kt1_EXmNQ
# 1            Delis  0bPLkL0QhhPO5kt1_EXmNQ
# 2          Italian  0bPLkL0QhhPO5kt1_EXmNQ
# 3         Bakeries  0bPLkL0QhhPO5kt1_EXmNQ
# 4      Restaurants  0bPLkL0QhhPO5kt1_EXmNQ
# ...            ...                     ...
# 66083         Bars  w_4xUt-1AyY2ZwKtnjW0Xg
# 66084   Gastropubs  w_4xUt-1AyY2ZwKtnjW0Xg
# 66085   Sandwiches  w_4xUt-1AyY2ZwKtnjW0Xg
# 66086    Nightlife  w_4xUt-1AyY2ZwKtnjW0Xg
# 66087  Restaurants  w_4xUt-1AyY2ZwKtnjW0Xg
#
# [66088 rows x 2 columns]

# %%
df_filtered
# Out:
#       category             business_id
# 0         Food  0bPLkL0QhhPO5kt1_EXmNQ
# 1        Delis  0bPLkL0QhhPO5kt1_EXmNQ
# 2      Italian  0bPLkL0QhhPO5kt1_EXmNQ
# 3     Bakeries  0bPLkL0QhhPO5kt1_EXmNQ
# 4  Restaurants  0bPLkL0QhhPO5kt1_EXmNQ

# %%
df_filtered.shape
# Out:
# (5, 2)

# %%
# Contar cuántas veces aparece cada categoría
df_category_counts = df_categories["category"].value_counts().reset_index()
df_category_counts.columns = ["category", "count"]

# Tomar las 20 categorías más comunes para mejor visualización
top_categories = df_category_counts.head(30)

# Graficar
plt.figure(figsize=(12, 6))
plt.barh(top_categories["category"], top_categories["count"], color="skyblue")
plt.xlabel("Frecuencia")
plt.ylabel("Categoría")
plt.title("Top 30 Categorías más frecuentes en df_categories")
plt.gca().invert_yaxis()  # Invertir el eje Y para que la más frecuente esté arriba

# %%
df_businessFL = df_business1[df_business1['state'] == 'FL']

# %%
df_filtered.head()
# Out:
#       category             business_id
# 0         Food  0bPLkL0QhhPO5kt1_EXmNQ
# 1        Delis  0bPLkL0QhhPO5kt1_EXmNQ
# 2      Italian  0bPLkL0QhhPO5kt1_EXmNQ
# 3     Bakeries  0bPLkL0QhhPO5kt1_EXmNQ
# 4  Restaurants  0bPLkL0QhhPO5kt1_EXmNQ

# %%
df_filtered.shape
# Out:
# (5, 2)

# %%
df_businessFL.shape
# Out:
# (26329, 14)

# %%
df_businessFL["hours"].head()
# Out:
# 10    {'Monday': '9:30-21:30', 'Tuesday': '9:30-21:3...
# 13    {'Monday': '7:30-15:30', 'Tuesday': '7:30-15:3...
# 14    {'Monday': '10:0-18:0', 'Tuesday': '10:0-20:0'...
# 16    {'Monday': '0:0-0:0', 'Tuesday': '8:0-17:0', '...
# 17    {'Monday': '10:0-19:0', 'Tuesday': '10:0-19:0'...
# Name: hours, dtype: object

# %%
df_states = df_business1['state'].value_counts().reset_index()
df_states
# Out:
#    state  count
# 0     PA  34039
# 1     FL  26329
# 2     TN  12056
# 3     IN  11246
# 4     MO  10913
# 5     LA   9924
# 6     AZ   9912
# 7     NJ   8536
# 8     NV   7715
# 9     AB   5573
# 10    CA   5203
# 11    ID   4467
# 12    DE   2265
# 13    IL   2144
# 14    TX      4
# 15    CO      3
# 16    WA      2
# 17    HI      2
# 18    MA      2
# 19    NC      1
# 20    UT      1
# 21    MT      1
# 22    MI      1
# 23    SD      1
# 24   XMS      1
# 25    VI      1
# 26    VT      1

# %%
df_business1[df_business1['state'] == 'VT']
# Out:
#                    business_id               name           address  \
# 144015  aXvUO0KwkD3Hp5WrY52zLw  Brookhaven Market  3510 Edgmont Ave
#
#               city state postal_code   latitude  longitude stars review_count  \
# 144015  Brookhaven    VT       19015  39.869814 -75.384818   4.0            8
#
#        is_open                                         attributes  \
# 144015       1  {'BusinessAcceptsCreditCards': 'True', 'Restau...
#
#                             categories  \
# 144015  Restaurants;Grocery;Food;Delis
#
#                                                     hours
# 144015  {'Monday': '8:0-20:0', 'Tuesday': '8:0-20:0', ...

# %%
df_business1.head(2)
# Out:
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara   NaN       93101
# 1  87 Grasso Plaza Shopping Center         Affton   NaN       63123
#
#     latitude   longitude stars  review_count is_open  \
# 0  34.426679 -119.711197   5.0             7       0
# 1  38.551126  -90.335695   3.0            15       1
#
#                                attributes  \
# 0           {'ByAppointmentOnly': 'True'}
# 1  {'BusinessAcceptsCreditCards': 'True'}
#
#                                           categories  \
# 0  Doctors, Traditional Chinese Medicine, Naturop...
# 1  Shipping Centers, Local Services, Notaries, Ma...
#
#                                                hours
# 0                                               None
# ...

# %%
df_filtrado = df_business1[df_business1['categories'].str.contains('Restaurants', case=False, na=False)]

# %%
df_filtrado.shape
# Out:
# (52268, 14)

# %%
# Palabras más comunes
from collections import Counter
import nltk
from nltk.corpus import stopwords

# %%
# Descargar stopwords si no están disponibles
nltk.download('stopwords')

# Definir las palabras de parada
stop_words = set(stopwords.words('english'))

# Asegurar que no haya valores nulos y reemplazar ", " por ";" y espacios por "_"
df_business1['categories'] = df_business1['categories'].fillna('').str.replace(', ', ';').str.replace(' ', '_')

# Unir todas las categorías y dividirlas en palabras individuales
all_words = ';'.join(df_business1['categories']).split(';')

# Filtrar palabras que no sean stopwords
filtered_words = [word for word in all_words if word.lower() not in stop_words]

# Contar las palabras más comunes
word_counts = Counter(filtered_words)

# Mostrar las 10 palabras más comunes
print(word_counts.most_common(10))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\anavi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# C:\Users\anavi\AppData\Local\Temp\ipykernel_33516\2399182401.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_business1['categories'] = df_business1['categories'].fillna('').str.replace(', ', ';').str.replace(' ', '_')
# [('Restaurants', 52268), ('Food', 27781), ('Shopping', 24395), ('Home_Services', 14356), ('Beauty_&_Spas', 14292), ('Nightlife', 12281), ('Health_&_Medical', 11890), ('Local_Services', 11198), ('Bars', 11065), ('Automotive', 10773)]

# %%
word_counts
# Out:
# Counter({'Restaurants': 52268,
#          'Food': 27781,
#          'Shopping': 24395,
#          'Home_Services': 14356,
#          'Beauty_&_Spas': 14292,
#          'Nightlife': 12281,
#          'Health_&_Medical': 11890,
#          'Local_Services': 11198,
#          'Bars': 11065,
#          'Automotive': 10773,
#          'Event_Planning_&_Services': 9895,
#          'Sandwiches': 8366,
#          'American_(Traditional)': 8139,
#          'Active_Life': 7687,
#          'Pizza': 7093,
#          'Coffee_&_Tea': 6703,
#          'Fast_Food': 6472,
#          'Breakfast_&_Brunch': 6239,
#          'American_(New)': 6097,
#          'Hotels_&_Travel': 5857,
#          'Home_&_Garden': 5799,
#          'Fashion': 5739,
#          'Burgers': 5636,
#          'Arts_&_Entertainment': 5434,
#          'Auto_Repair': 5433,
#          'Hair_Salons': 5046,
#          'Nail_Salons': 4621,
#          'Mexican': 4600,
#          'Italian': 4573,
#          'Specialty_Food': 4233,
# ...

# %%
df_filtrado.shape
# Out:
# (52268, 15)

# %%
df_filtrado.head(5)
# Out:
#                business_id                             name  \
# 5   CF33F8-E6oudUQ46HnavjQ                   Sonic Drive-In
# 9   bBDDEgkFA1Otx9Lfe7BZUQ                   Sonic Drive-In
# 36  2xVsWBNFwZOxIOdd9Mwnww         Cheeseburger In Paradise
# 60  Si6LXSR9gvAbmgO5DzV2cw  Lafitte's Landing Seafood House
# 79  pJfh3Ct8iL58NZa8ta-a5w          Top Shelf Sports Lounge
#
#                     address           city state postal_code   latitude  \
# 5             615 S Main St   Ashland City    AZ       37015  36.269593
# 9       2312 Dickerson Pike      Nashville    MO       37207  36.208102
# 36     116 N Pottstown Pike          Exton    PA       19341  40.029962
# 60        1700 Lapalco Blvd         Harvey    PA       70058  29.875482
# 79  3173 Cypress Ridge Blvd  Wesley Chapel    PA       33544  28.196252
#
#     longitude stars  review_count is_open  \
# 5  -87.058943   2.0             6       1
# 9  -86.768170   1.5            10       1
# ...

# %%
df_business1.to_csv('Business.csv', index=False, encoding='utf-8')

# %%
df_categories.to_csv('Categories.csv', index=False, encoding='utf-8')

# %%
# Contar la cantidad de valores en cada celda

df_business1['count'] = df_business1['categories'].fillna('').apply(lambda x: len(x.split(', ')))
# Out:
# C:\Users\anavi\AppData\Local\Temp\ipykernel_30792\3946331038.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_business1['count'] = df_business1['categories'].fillna('').apply(lambda x: len(x.split(', ')))

# %%
df_count = df_business1[df_business1["count"] >= 16]

# %%
df_count.shape
# Out:
# (148, 15)

# %%
df_count.head(2)
# Out:
#                  business_id                                name  \
# 1357  hlqnFy34n8tnVNMq-pO34g                        Best IT Guru
# 1554  Wz5Ky7sW5jyCkouCCsdP_w  Out of the Closet - St. Petersburg
#
#                   address            city state postal_code   latitude  \
# 1357  7211 Rising Sun Ave    Philadelphia    IL       19111  40.059829
# 1554      3400 26th Ave S  St. Petersburg    FL       33711  27.744402
#
#       longitude stars  review_count is_open  \
# 1357 -75.085466   4.0            10       1
# 1554 -82.679860   4.0            21       1
#
#                                              attributes  \
# 1357  {'BusinessAcceptsCreditCards': 'True', 'ByAppo...
# 1554  {'BusinessAcceptsBitcoin': 'False', 'DogsAllow...
#
#                                              categories  \
# 1357  Shopping, Computers, Specialty Schools, Market...
# 1554  Walk-in Clinics, Medical Supplies, Pharmacy, F...
#
#                                                   hours  count
# ...

# %%
plt.figure(figsize=(8,5))
plt.hist(df_business1['count'], bins=20, edgecolor='black')
plt.xlabel('Cantidad de Categorías')
plt.ylabel('Frecuencia')
plt.title('Distribución de la Cantidad de Categorías')
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(df_business1['count'], bins=10, edgecolor='black')  # Reducimos el número de bins
plt.xlabel('Cantidad de Categorías')
plt.ylabel('Frecuencia')
plt.title('Distribución de la Cantidad de Categorías')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

plt.figure(figsize=(10,6))

# Crear los intervalos de 2 en 2
bins = np.arange(0, df_business1['count'].max() + 2, 2)  # Máximo valor +2 para incluir el último

# Graficar con huecos entre las barras
sns.histplot(df_business1['count'], bins=bins, edgecolor='black', discrete=True)

plt.xlabel('Cantidad de Categorías')
plt.ylabel('Frecuencia')
plt.title('Distribución de la Cantidad de Categorías')

# Ajustar los ticks del eje X para que vayan de 2 en 2
plt.xticks(bins)

plt.show()
